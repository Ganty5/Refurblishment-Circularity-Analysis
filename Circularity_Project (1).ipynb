# %%
import pandas as pd

# %%
# Load the data
Rebu = pd.read_csv('C:/Users/Chika/Downloads/My data.csv', delimiter=';')
# Out:
# C:\Users\Chika\AppData\Local\Temp\ipykernel_10668\2450063915.py:2: DtypeWarning: Columns (48,49,53,54,63,65,66,67,68,69,70,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,121,122,123,130,135,140,145,153,159,160,161,162,163,164,165,166,167,168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,189,191) have mixed types. Specify dtype option on import or set low_memory=False.
#   Rebu = pd.read_csv('C:/Users/Chika/Downloads/My data.csv', delimiter=';')

# %%
# Display the first few rows to confirm successful loading
print(Rebu.head())
# Out:
#        Type  Subtype                                      Serial.Number  \
# 0  Computer   Laptop  502cc66f4fec1dbb4d78e21eec5cd8a86f77add220595f...
# 1  Computer   Laptop  7d2c130757384103e27f588b3410ea3e65006425b96d66...
# 2  Computer   Laptop  a2e4fbff33e2c007470437d0c24a228dcb7fcd57a80aaa...
# 3  Computer   Laptop  d39cf177a84019b3a18f8bdc6e3064040c3ac052b9cafe...
# 4  Computer  Netbook  ee41bc37166a40642be5dbd58f210b9ec5a06fe2245272...
#
#                            Model     Manufacturer  \
# 0                  MacBookAir6,1            Apple
# 1                  MacBookPro8,1            Apple
# 2  HP Compaq 6715b (GR667ET#ABE)  Hewlett-Packard
# 3  HP Compaq 6730b (NN204ET#ABE)  Hewlett-Packard
# 4               HP ProBook 6360b  Hewlett-Packard
#
#                       Registered.in  \
# 0  2017-04-27 08:18:38.571000+00:00
# 1  2017-04-27 08:10:39.371000+00:00
# 2         2016-04-26 07:37:26+00:00
# 3         2016-04-26 07:37:23+00:00
# 4  2018-07-27 10:05:48.290000+00:00
#
#                                       Processor  RAM.GB    HDD.MB  \
# 0                                           NaN     0.0       0.0
# 1                                           NaN     0.0       0.0
# 2  AMD Turion(tm) 64 X2 Mobile Technology TL-58  1024.0  114473.0
# 3    Intel(R) Core(TM)2 Duo CPU P8700 @ 2.53GHz  4096.0  238475.0
# 4             Intel Core i5-2520M CPU @ 2.50GHz  4096.0  305245.0
#
#   Condition.Score  ... OpticalDrive.4.manufacturer OpticalDrive.4.model  \
# 0             NaN  ...                         NaN                  NaN
# 1             NaN  ...                         NaN                  NaN
# 2             NaN  ...                         NaN                  NaN
# 3             NaN  ...                         NaN                  NaN
# 4            4,82  ...                         NaN                  NaN
#
#   RamModule.5 RamModule.5.manufacturer RamModule.5.model RamModule.5.size  \
# 0         NaN                      NaN               NaN              NaN
# 1         NaN                      NaN               NaN              NaN
# 2         NaN                      NaN               NaN              NaN
# 3         NaN                      NaN               NaN              NaN
# 4         NaN                      NaN               NaN              NaN
#
#   RamModule.5.speed HardDrive.3 HardDrive.3.manufacturer HardDrive.3.model
# 0               NaN         NaN                      NaN               NaN
# 1               NaN         NaN                      NaN               NaN
# 2               NaN         NaN                      NaN               NaN
# 3               NaN         NaN                      NaN               NaN
# 4               NaN         NaN                      NaN               NaN
#
# [5 rows x 192 columns]

# %%
Rebu = Rebu[['Type', 'Subtype', 'Model', 'Manufacturer', 'Registered.in', 'Processor', 'RAM.GB', 'HDD.MB', 'Condition.Score', 'Condition']]

# %%
print(Rebu.head())
# Out:
#        Type  Subtype                          Model     Manufacturer  \
# 0  Computer   Laptop                  MacBookAir6,1            Apple
# 1  Computer   Laptop                  MacBookPro8,1            Apple
# 2  Computer   Laptop  HP Compaq 6715b (GR667ET#ABE)  Hewlett-Packard
# 3  Computer   Laptop  HP Compaq 6730b (NN204ET#ABE)  Hewlett-Packard
# 4  Computer  Netbook               HP ProBook 6360b  Hewlett-Packard
#
#                       Registered.in  \
# 0  2017-04-27 08:18:38.571000+00:00
# 1  2017-04-27 08:10:39.371000+00:00
# 2         2016-04-26 07:37:26+00:00
# 3         2016-04-26 07:37:23+00:00
# 4  2018-07-27 10:05:48.290000+00:00
#
#                                       Processor  RAM.GB    HDD.MB  \
# 0                                           NaN     0.0       0.0
# 1                                           NaN     0.0       0.0
# 2  AMD Turion(tm) 64 X2 Mobile Technology TL-58  1024.0  114473.0
# 3    Intel(R) Core(TM)2 Duo CPU P8700 @ 2.53GHz  4096.0  238475.0
# 4             Intel Core i5-2520M CPU @ 2.50GHz  4096.0  305245.0
#
#   Condition.Score Condition
# 0             NaN       NaN
# 1             NaN       NaN
# 2             NaN       NaN
# 3             NaN       NaN
# 4            4,82      High

# %%
# Check for missing values
print(Rebu.isnull().sum())
# Out:
# Type                  0
# Subtype            1440
# Model              1544
# Manufacturer       1452
# Registered.in         0
# Processor          2970
# RAM.GB              426
# HDD.MB              426
# Condition.Score    5470
# Condition          5470
# dtype: int64

# %%
# Check the unique values in Condition.Score
print(Rebu['Condition.Score'].unique())
# Out:
# [nan '4,82' '4,79' '4,87' '2,72' '4,59' '4,66' '4,67' '4,51' '4,56' '4,65'
#  '4,6' '4,64' '4,17' '4,18' '4,16' '1,53' '3,19' '4,04' '2,5' '3,35'
#  '1,58' '0,71' '4,61' '0' '0,33' '0,03' '2,66' '1,03' '3,53' '3,7' '2,15'
#  '2,2' '2,34' '2,37' '2,47' '2,44' '2,29' '2,46' '3,49' '0,93' '3,38'
#  '2,9' '4,41' '4,47' '3,1' '3,31' '3,11' '2,22' '3,33' '2,36' '4,44'
#  '4,24' '2,28' '1,91' '1,86' '4,53' '4,45' '4,22' '4,36' '4,52' '4,23'
#  '4,31' '4,19' '4,03' '4,02' '3,36' '2,81' '2,18' '4,76' '4,77' '4,73'
#  '4,81' '2,88' '3,01' '4,21' '1,44' '4,78' '4,71' '4,72' '4,69' '4,14'
#  '3,6' '3,67' '3,99' '3,14' '4,57' '1,73' '4,58' '4,29' '2,1' '2,11'
#  '1,22' '1,4' '3,12' '4,75' '4,63' '2,99' '3,52' '3,32' '3,39' '1,17'
#  '3,46' '4,34' '3,66' '3,48' '3,13' '4,55' '0,86' '1,72' '4,38' '3,17'
#  '1,95' '0,5' '3,76' '2,19' '4,35' '4,54' '3,21' '1,38' '4,08' '2,38'
#  '2,16' '2,39' '3,18' '3,26' '2,75' '4,84' '2,87' '2,17' '2,32' '3,54'
#  '2,13' '1,9' '2,27' '2,09' '2,79' '3,71' '1,43' '4,62' '4,1' '3,41' '4,3'
#  '4,68' '3,4' '4,26' '3,37' '4,11' '3,42' '2,91' '4,32' '4,25' '3,81'
#  '3,45' '3,23' '2,48' '2,23' '3,63' '2,84' '2,98' '1,66' '3,02' '3,58'
#  '1,09' '2,52' '3,15' '1,92' '4,33' '4,2' '2,12' '1,89' '2,25' '1,88'
#  '1,99' '2,35' '1,79' '1,49' '1,83' '3,2' '3,05' '2,02' '2,96' '2,89'
#  '1,96' '2,26' '1,55' '2,24' '4,42' '2,21' '2,7' '2,41' '2,08' '2,85'
#  '2,4' '3,55' '3,24' '3,09' '3,3' '3,04' '1,32' '1,64' '1,31' '1,69'
#  '1,84' '0,95' '0,97' '1,08' '0,87' '2,33' '2,51' '1,13' '1,2' '3,34'
#  '2,54' '2,61' '2,14' '2,43' '2,03' '2,49' '3,29' '3,28' '3,25' '4,4' '3'
#  '2' '1,47' '1,59' '2,55' '2,01' '0,99' '0,78' '1,78' '1,6' '1,85' '1,77'
#  '1,74' '2,31' '1,24' '4,13' '3,51' '4,12' '4,5' '3,64' '3,8' '4,05' '4'
#  '4,43' '4,15' '3,82' '3,79' '3,62' '4,46' '3,98' '2,94' '3,75' '2,58'
#  '4,49' '4,48' '3,74' '4,01' '2,71' '2,57' '2,82' '2,6' '2,83' '2,56'
#  '4,39' '3,08' '2,07' '3,47' '3,44' '1,67' '1,7' '2,93' '4,27' '3,87'
#  '2,63' '3,5' '2,59' '3,22' '1,62' '2,64' '4,28' '2,73' '2,42' '3,73'
#  '2,8' '2,62' '3,61' '4,37' '4,86' '3,69' '3,65' '3,06' '3,07' '3,83'
#  '3,93' '2,45' '2,68' '3,68' '3,72' '3,97' '1,23' '1,94' '1,81' '2,53'
#  '0,63' '1,54' '2,67' '0,45' '2,3' '2,06' '2,05' '1,35' '0,73' '1,29'
#  '1,63' '2,04' '1,18' '1,5' '3,43' '1,8' '1,42' '1,33' '1,14' '1,3' '1'
#  '1,37' '1,11' '0,65' '1,87' '0,7' '1,27' '1,57' '1,93' '1,71' '0,55'
#  '1,28' '0,88' '0,94' '1,75' '1,15' '1,07' '1,97' '4,88' '0,92' '0,82'
#  '1,12' '2,74' '3,56' '3,57' '3,88' '3,77' '2,86' '3,78' '1,39' '0,83'
#  '0,74' '4,9' '4,83' '4,06' '4,7' '4,85' '0,53' '3,59' '2,76' '3,16' '1,1'
#  '4,74']

# %%
# Check the data types
print(Rebu.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8458 entries, 0 to 8457
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             8458 non-null   object
#  1   Subtype          7018 non-null   object
#  2   Model            6914 non-null   object
#  3   Manufacturer     7006 non-null   object
#  4   Registered.in    8458 non-null   object
#  5   Processor        5488 non-null   object
#  6   RAM.GB           8032 non-null   float64
#  7   HDD.MB           8032 non-null   float64
#  8   Condition.Score  2988 non-null   object
#  9   Condition        2988 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 660.9+ KB
# None

# %%
# Handle missing values in other columns (example: replace NaN with 'Unknown' for categorical columns)
Rebu['Subtype'] = Rebu['Subtype'].fillna('Unknown')
Rebu['Model'] = Rebu['Model'].fillna('Unknown')
Rebu['Manufacturer'] = Rebu['Manufacturer'].fillna('Unknown')

# Replace numerical columns with mean/median values
Rebu['RAM.GB'] = Rebu['RAM.GB'].fillna(Rebu['RAM.GB'].median())
Rebu['HDD.MB'] = Rebu['HDD.MB'].fillna(Rebu['HDD.MB'].median())

# %%
print(Rebu.isnull().sum())
# Out:
# Type                  0
# Subtype               0
# Model                 0
# Manufacturer          0
# Registered.in         0
# Processor          2970
# RAM.GB                0
# HDD.MB                0
# Condition.Score    5470
# Condition          5470
# dtype: int64

# %%
# Fill missing values for 'Processor' with 'Unknown'
Rebu['Processor'] = Rebu['Processor'].fillna('Unknown')

# %%
# Fill missing values in 'Condition' with 'Unknown'
Rebu['Condition'] = Rebu['Condition'].fillna('Unknown')

# %%
print(Rebu.isnull().sum())
# Out:
# Type                  0
# Subtype               0
# Model                 0
# Manufacturer          0
# Registered.in         0
# Processor             0
# RAM.GB                0
# HDD.MB                0
# Condition.Score    5470
# Condition             0
# dtype: int64

# %%
Rebu['Condition.Score'] = Rebu['Condition.Score'].fillna(-1)

# %%
print(Rebu.isnull().sum())
# Out:
# Type               0
# Subtype            0
# Model              0
# Manufacturer       0
# Registered.in      0
# Processor          0
# RAM.GB             0
# HDD.MB             0
# Condition.Score    0
# Condition          0
# dtype: int64

# %%
print(Rebu['Condition.Score'].unique())
# Out:
# [-1 '4,82' '4,79' '4,87' '2,72' '4,59' '4,66' '4,67' '4,51' '4,56' '4,65'
#  '4,6' '4,64' '4,17' '4,18' '4,16' '1,53' '3,19' '4,04' '2,5' '3,35'
#  '1,58' '0,71' '4,61' '0' '0,33' '0,03' '2,66' '1,03' '3,53' '3,7' '2,15'
#  '2,2' '2,34' '2,37' '2,47' '2,44' '2,29' '2,46' '3,49' '0,93' '3,38'
#  '2,9' '4,41' '4,47' '3,1' '3,31' '3,11' '2,22' '3,33' '2,36' '4,44'
#  '4,24' '2,28' '1,91' '1,86' '4,53' '4,45' '4,22' '4,36' '4,52' '4,23'
#  '4,31' '4,19' '4,03' '4,02' '3,36' '2,81' '2,18' '4,76' '4,77' '4,73'
#  '4,81' '2,88' '3,01' '4,21' '1,44' '4,78' '4,71' '4,72' '4,69' '4,14'
#  '3,6' '3,67' '3,99' '3,14' '4,57' '1,73' '4,58' '4,29' '2,1' '2,11'
#  '1,22' '1,4' '3,12' '4,75' '4,63' '2,99' '3,52' '3,32' '3,39' '1,17'
#  '3,46' '4,34' '3,66' '3,48' '3,13' '4,55' '0,86' '1,72' '4,38' '3,17'
#  '1,95' '0,5' '3,76' '2,19' '4,35' '4,54' '3,21' '1,38' '4,08' '2,38'
#  '2,16' '2,39' '3,18' '3,26' '2,75' '4,84' '2,87' '2,17' '2,32' '3,54'
#  '2,13' '1,9' '2,27' '2,09' '2,79' '3,71' '1,43' '4,62' '4,1' '3,41' '4,3'
#  '4,68' '3,4' '4,26' '3,37' '4,11' '3,42' '2,91' '4,32' '4,25' '3,81'
#  '3,45' '3,23' '2,48' '2,23' '3,63' '2,84' '2,98' '1,66' '3,02' '3,58'
#  '1,09' '2,52' '3,15' '1,92' '4,33' '4,2' '2,12' '1,89' '2,25' '1,88'
#  '1,99' '2,35' '1,79' '1,49' '1,83' '3,2' '3,05' '2,02' '2,96' '2,89'
#  '1,96' '2,26' '1,55' '2,24' '4,42' '2,21' '2,7' '2,41' '2,08' '2,85'
#  '2,4' '3,55' '3,24' '3,09' '3,3' '3,04' '1,32' '1,64' '1,31' '1,69'
#  '1,84' '0,95' '0,97' '1,08' '0,87' '2,33' '2,51' '1,13' '1,2' '3,34'
#  '2,54' '2,61' '2,14' '2,43' '2,03' '2,49' '3,29' '3,28' '3,25' '4,4' '3'
#  '2' '1,47' '1,59' '2,55' '2,01' '0,99' '0,78' '1,78' '1,6' '1,85' '1,77'
#  '1,74' '2,31' '1,24' '4,13' '3,51' '4,12' '4,5' '3,64' '3,8' '4,05' '4'
#  '4,43' '4,15' '3,82' '3,79' '3,62' '4,46' '3,98' '2,94' '3,75' '2,58'
#  '4,49' '4,48' '3,74' '4,01' '2,71' '2,57' '2,82' '2,6' '2,83' '2,56'
#  '4,39' '3,08' '2,07' '3,47' '3,44' '1,67' '1,7' '2,93' '4,27' '3,87'
#  '2,63' '3,5' '2,59' '3,22' '1,62' '2,64' '4,28' '2,73' '2,42' '3,73'
#  '2,8' '2,62' '3,61' '4,37' '4,86' '3,69' '3,65' '3,06' '3,07' '3,83'
#  '3,93' '2,45' '2,68' '3,68' '3,72' '3,97' '1,23' '1,94' '1,81' '2,53'
#  '0,63' '1,54' '2,67' '0,45' '2,3' '2,06' '2,05' '1,35' '0,73' '1,29'
#  '1,63' '2,04' '1,18' '1,5' '3,43' '1,8' '1,42' '1,33' '1,14' '1,3' '1'
#  '1,37' '1,11' '0,65' '1,87' '0,7' '1,27' '1,57' '1,93' '1,71' '0,55'
#  '1,28' '0,88' '0,94' '1,75' '1,15' '1,07' '1,97' '4,88' '0,92' '0,82'
#  '1,12' '2,74' '3,56' '3,57' '3,88' '3,77' '2,86' '3,78' '1,39' '0,83'
#  '0,74' '4,9' '4,83' '4,06' '4,7' '4,85' '0,53' '3,59' '2,76' '3,16' '1,1'
#  '4,74']

# %%
Rebu.head(30)
# Out:
#         Type  Subtype                          Model     Manufacturer  \
# 0   Computer   Laptop                  MacBookAir6,1            Apple
# 1   Computer   Laptop                  MacBookPro8,1            Apple
# 2   Computer   Laptop  HP Compaq 6715b (GR667ET#ABE)  Hewlett-Packard
# 3   Computer   Laptop  HP Compaq 6730b (NN204ET#ABE)  Hewlett-Packard
# 4   Computer  Netbook               HP ProBook 6360b  Hewlett-Packard
# 5   Computer  Netbook               HP ProBook 6360b  Hewlett-Packard
# 6   Computer  Netbook              HP ProBook 640 G1  Hewlett-Packard
# 7   Computer  Netbook                        2522AT6           LENOVO
# 8   Computer  Netbook                        4180AJ3           LENOVO
# 9   Computer  Netbook              HP ProBook 640 G1  Hewlett-Packard
# 10    Device  Unknown                        Unknown          Unknown
# 11    Device  Unknown                        Unknown          Unknown
# 12    Device  Unknown                        Unknown          Unknown
# 13    Device  Unknown                        Unknown          Unknown
# 14  Computer  Netbook                        4180AJ3           LENOVO
# 15    Device  Unknown                        Unknown          Unknown
# 16    Device  Unknown                        Unknown          Unknown
# 17    Device  Unknown                        Unknown          Unknown
# 18    Device  Unknown                        Unknown          Unknown
# 19    Device  Unknown                        Unknown          Unknown
# 20    Device  Unknown                        Unknown          Unknown
# 21    Device  Unknown                        Unknown          Unknown
# 22    Device  Unknown                        Unknown          Unknown
# 23    Device  Unknown                        Unknown          Unknown
# 24    Device  Unknown                        Unknown          Unknown
# 25    Device  Unknown                        Unknown          Unknown
# 26    Device  Unknown                        Unknown          Unknown
# 27    Device  Unknown                        Unknown          Unknown
# 28    Device  Unknown                        Unknown          Unknown
# 29    Device  Unknown                        Unknown          Unknown
#
#                        Registered.in  \
# 0   2017-04-27 08:18:38.571000+00:00
# 1   2017-04-27 08:10:39.371000+00:00
# 2          2016-04-26 07:37:26+00:00
# 3          2016-04-26 07:37:23+00:00
# 4   2018-07-27 10:05:48.290000+00:00
# 5   2018-07-27 10:05:48.460000+00:00
# 6   2018-07-27 10:06:19.227000+00:00
# 7   2018-07-27 12:04:23.712000+00:00
# 8   2018-07-27 12:04:23.776000+00:00
# 9   2018-07-31 13:35:46.224000+00:00
# 10  2018-07-31 13:35:46.289000+00:00
# 11  2018-07-31 13:35:46.338000+00:00
# 12  2018-07-31 13:35:46.389000+00:00
# 13  2018-07-31 13:35:46.441000+00:00
# 14  2018-07-31 13:35:46.494000+00:00
# 15  2018-08-03 13:56:09.565000+00:00
# 16  2018-08-03 13:56:09.651000+00:00
# 17  2018-08-03 13:56:09.711000+00:00
# 18  2018-08-03 13:56:09.766000+00:00
# 19  2018-08-03 13:56:09.825000+00:00
# 20  2018-08-03 13:56:09.880000+00:00
# 21  2018-08-03 13:56:09.933000+00:00
# 22  2018-08-03 13:56:09.988000+00:00
# 23  2018-08-03 13:56:10.049000+00:00
# 24  2018-08-03 13:56:10.139000+00:00
# 25  2018-08-03 14:13:16.122000+00:00
# 26  2018-09-07 15:56:15.593000+00:00
# 27  2018-09-07 15:56:15.674000+00:00
# 28  2018-09-07 15:56:15.768000+00:00
# 29  2018-09-07 15:56:15.837000+00:00
#
#                                        Processor  RAM.GB    HDD.MB  \
# 0                                        Unknown     0.0       0.0
# 1                                        Unknown     0.0       0.0
# 2   AMD Turion(tm) 64 X2 Mobile Technology TL-58  1024.0  114473.0
# 3     Intel(R) Core(TM)2 Duo CPU P8700 @ 2.53GHz  4096.0  238475.0
# 4              Intel Core i5-2520M CPU @ 2.50GHz  4096.0  305245.0
# 5              Intel Core i5-2520M CPU @ 2.50GHz  4096.0  238475.0
# 6              Intel Core i5-4210M CPU @ 2.60GHz  4096.0  476940.0
# 7                                        Unknown     0.0       0.0
# 8              Intel Core i5-2520M CPU @ 2.50GHz     0.0       0.0
# 9              Intel Core i5-4200M CPU @ 2.50GHz  4096.0  476940.0
# 10                                       Unknown     0.0       0.0
# 11                                       Unknown     0.0       0.0
# 12                                       Unknown     0.0       0.0
# 13                                       Unknown     0.0       0.0
# 14             Intel Core i5-2520M CPU @ 2.50GHz     0.0       0.0
# 15                                       Unknown     0.0       0.0
# 16                                       Unknown     0.0       0.0
# 17                                       Unknown     0.0       0.0
# 18                                       Unknown     0.0       0.0
# 19                                       Unknown     0.0       0.0
# 20                                       Unknown     0.0       0.0
# 21                                       Unknown     0.0       0.0
# 22                                       Unknown     0.0       0.0
# 23                                       Unknown     0.0       0.0
# 24                                       Unknown     0.0       0.0
# 25                                       Unknown     0.0       0.0
# 26                                       Unknown     0.0       0.0
# 27                                       Unknown     0.0       0.0
# 28                                       Unknown     0.0       0.0
# 29                                       Unknown     0.0       0.0
#
#    Condition.Score Condition
# 0               -1   Unknown
# 1               -1   Unknown
# 2               -1   Unknown
# 3               -1   Unknown
# 4             4,82      High
# 5             4,79      High
# 6             4,87      High
# 7             2,72       Low
# 8             4,59      High
# 9             4,66      High
# 10              -1   Unknown
# 11              -1   Unknown
# 12              -1   Unknown
# 13              -1   Unknown
# 14              -1   Unknown
# 15              -1   Unknown
# 16              -1   Unknown
# 17              -1   Unknown
# 18              -1   Unknown
# 19              -1   Unknown
# 20              -1   Unknown
# 21              -1   Unknown
# 22              -1   Unknown
# 23              -1   Unknown
# 24              -1   Unknown
# 25              -1   Unknown
# 26              -1   Unknown
# 27              -1   Unknown
# 28              -1   Unknown
# 29              -1   Unknown

# %%
# Drop rows where Condition.Score is -1
Rebu = Rebu[Rebu['Condition.Score'] != -1]

# %%
# Verify the rows are dropped
print(Rebu['Condition.Score'].unique())
# Out:
# ['4,82' '4,79' '4,87' '2,72' '4,59' '4,66' '4,67' '4,51' '4,56' '4,65'
#  '4,6' '4,64' '4,17' '4,18' '4,16' '1,53' '3,19' '4,04' '2,5' '3,35'
#  '1,58' '0,71' '4,61' '0' '0,33' '0,03' '2,66' '1,03' '3,53' '3,7' '2,15'
#  '2,2' '2,34' '2,37' '2,47' '2,44' '2,29' '2,46' '3,49' '0,93' '3,38'
#  '2,9' '4,41' '4,47' '3,1' '3,31' '3,11' '2,22' '3,33' '2,36' '4,44'
#  '4,24' '2,28' '1,91' '1,86' '4,53' '4,45' '4,22' '4,36' '4,52' '4,23'
#  '4,31' '4,19' '4,03' '4,02' '3,36' '2,81' '2,18' '4,76' '4,77' '4,73'
#  '4,81' '2,88' '3,01' '4,21' '1,44' '4,78' '4,71' '4,72' '4,69' '4,14'
#  '3,6' '3,67' '3,99' '3,14' '4,57' '1,73' '4,58' '4,29' '2,1' '2,11'
#  '1,22' '1,4' '3,12' '4,75' '4,63' '2,99' '3,52' '3,32' '3,39' '1,17'
#  '3,46' '4,34' '3,66' '3,48' '3,13' '4,55' '0,86' '1,72' '4,38' '3,17'
#  '1,95' '0,5' '3,76' '2,19' '4,35' '4,54' '3,21' '1,38' '4,08' '2,38'
#  '2,16' '2,39' '3,18' '3,26' '2,75' '4,84' '2,87' '2,17' '2,32' '3,54'
#  '2,13' '1,9' '2,27' '2,09' '2,79' '3,71' '1,43' '4,62' '4,1' '3,41' '4,3'
#  '4,68' '3,4' '4,26' '3,37' '4,11' '3,42' '2,91' '4,32' '4,25' '3,81'
#  '3,45' '3,23' '2,48' '2,23' '3,63' '2,84' '2,98' '1,66' '3,02' '3,58'
#  '1,09' '2,52' '3,15' '1,92' '4,33' '4,2' '2,12' '1,89' '2,25' '1,88'
#  '1,99' '2,35' '1,79' '1,49' '1,83' '3,2' '3,05' '2,02' '2,96' '2,89'
#  '1,96' '2,26' '1,55' '2,24' '4,42' '2,21' '2,7' '2,41' '2,08' '2,85'
#  '2,4' '3,55' '3,24' '3,09' '3,3' '3,04' '1,32' '1,64' '1,31' '1,69'
#  '1,84' '0,95' '0,97' '1,08' '0,87' '2,33' '2,51' '1,13' '1,2' '3,34'
#  '2,54' '2,61' '2,14' '2,43' '2,03' '2,49' '3,29' '3,28' '3,25' '4,4' '3'
#  '2' '1,47' '1,59' '2,55' '2,01' '0,99' '0,78' '1,78' '1,6' '1,85' '1,77'
#  '1,74' '2,31' '1,24' '4,13' '3,51' '4,12' '4,5' '3,64' '3,8' '4,05' '4'
#  '4,43' '4,15' '3,82' '3,79' '3,62' '4,46' '3,98' '2,94' '3,75' '2,58'
#  '4,49' '4,48' '3,74' '4,01' '2,71' '2,57' '2,82' '2,6' '2,83' '2,56'
#  '4,39' '3,08' '2,07' '3,47' '3,44' '1,67' '1,7' '2,93' '4,27' '3,87'
#  '2,63' '3,5' '2,59' '3,22' '1,62' '2,64' '4,28' '2,73' '2,42' '3,73'
#  '2,8' '2,62' '3,61' '4,37' '4,86' '3,69' '3,65' '3,06' '3,07' '3,83'
#  '3,93' '2,45' '2,68' '3,68' '3,72' '3,97' '1,23' '1,94' '1,81' '2,53'
#  '0,63' '1,54' '2,67' '0,45' '2,3' '2,06' '2,05' '1,35' '0,73' '1,29'
#  '1,63' '2,04' '1,18' '1,5' '3,43' '1,8' '1,42' '1,33' '1,14' '1,3' '1'
#  '1,37' '1,11' '0,65' '1,87' '0,7' '1,27' '1,57' '1,93' '1,71' '0,55'
#  '1,28' '0,88' '0,94' '1,75' '1,15' '1,07' '1,97' '4,88' '0,92' '0,82'
#  '1,12' '2,74' '3,56' '3,57' '3,88' '3,77' '2,86' '3,78' '1,39' '0,83'
#  '0,74' '4,9' '4,83' '4,06' '4,7' '4,85' '0,53' '3,59' '2,76' '3,16' '1,1'
#  '4,74']

# %%
Rebu.head(20)
# Out:
#          Type  Subtype              Model     Manufacturer  \
# 4    Computer  Netbook   HP ProBook 6360b  Hewlett-Packard
# 5    Computer  Netbook   HP ProBook 6360b  Hewlett-Packard
# 6    Computer  Netbook  HP ProBook 640 G1  Hewlett-Packard
# 7    Computer  Netbook            2522AT6           LENOVO
# 8    Computer  Netbook            4180AJ3           LENOVO
# 9    Computer  Netbook  HP ProBook 640 G1  Hewlett-Packard
# 71   Computer  Netbook  HP ProBook 640 G1  Hewlett-Packard
# 72   Computer  Netbook            1143K8G           LENOVO
# 200  Computer  Netbook            23301A8           LENOVO
# 201  Computer  Netbook            23301A8           LENOVO
# 227  Computer  Netbook  HP ProBook 650 G1  Hewlett-Packard
# 228  Computer  Netbook  HP ProBook 650 G1  Hewlett-Packard
# 229  Computer  Netbook  HP ProBook 650 G1  Hewlett-Packard
# 230  Computer  Netbook  HP ProBook 650 G1  Hewlett-Packard
# 231  Computer  Netbook   HP ProBook 6570b  Hewlett-Packard
# 232  Computer  Netbook  HP ProBook 650 G1  Hewlett-Packard
# 233  Computer  Netbook   HP ProBook 6570b  Hewlett-Packard
# 234  Computer  Netbook  HP ProBook 650 G1  Hewlett-Packard
# 235  Computer  Netbook   HP ProBook 6570b  Hewlett-Packard
# 236  Computer  Netbook   HP ProBook 6570b  Hewlett-Packard
#
#                         Registered.in                          Processor  \
# 4    2018-07-27 10:05:48.290000+00:00  Intel Core i5-2520M CPU @ 2.50GHz
# 5    2018-07-27 10:05:48.460000+00:00  Intel Core i5-2520M CPU @ 2.50GHz
# 6    2018-07-27 10:06:19.227000+00:00  Intel Core i5-4210M CPU @ 2.60GHz
# 7    2018-07-27 12:04:23.712000+00:00                            Unknown
# 8    2018-07-27 12:04:23.776000+00:00  Intel Core i5-2520M CPU @ 2.50GHz
# 9    2018-07-31 13:35:46.224000+00:00  Intel Core i5-4200M CPU @ 2.50GHz
# 71   2018-09-20 15:18:10.233000+00:00  Intel Core i5-4210M CPU @ 2.60GHz
# 72   2018-09-20 15:18:10.301000+00:00  Intel Core i5-2450M CPU @ 2.50GHz
# 200  2018-10-30 16:56:14.030000+00:00  Intel Core i5-3320M CPU @ 2.60GHz
# 201  2018-10-30 17:25:34.133000+00:00  Intel Core i5-3320M CPU @ 2.60GHz
# 227  2019-02-05 10:29:29.305000+00:00  Intel Core i5-4210M CPU @ 2.60GHz
# 228  2019-01-31 09:29:41.368000+00:00  Intel Core i5-4200M CPU @ 2.50GHz
# 229  2019-02-04 09:37:59.628000+00:00  Intel Core i5-4210M CPU @ 2.60GHz
# 230  2019-01-17 08:44:14.392000+00:00  Intel Core i5-4200M CPU @ 2.50GHz
# 231  2019-01-17 09:20:16.016000+00:00  Intel Core i3-2370M CPU @ 2.40GHz
# 232  2019-02-04 10:17:07.653000+00:00  Intel Core i5-4210M CPU @ 2.60GHz
# 233  2019-02-05 08:48:04.062000+00:00  Intel Core i5-3210M CPU @ 2.50GHz
# 234  2019-01-17 09:13:17.283000+00:00  Intel Core i5-4200M CPU @ 2.50GHz
# 235  2019-02-05 10:33:19.257000+00:00  Intel Core i5-3210M CPU @ 2.50GHz
# 236  2019-02-05 08:44:33.556000+00:00  Intel Core i3-2370M CPU @ 2.40GHz
#
#      RAM.GB    HDD.MB Condition.Score Condition
# 4    4096.0  305245.0            4,82      High
# 5    4096.0  238475.0            4,79      High
# 6    4096.0  476940.0            4,87      High
# 7       0.0       0.0            2,72       Low
# 8       0.0       0.0            4,59      High
# 9    4096.0  476940.0            4,66      High
# 71   4096.0  476940.0            4,67      High
# 72   6144.0  305245.0            4,51      High
# 200  8192.0  305245.0            4,56      High
# 201  8192.0  305245.0            4,56      High
# 227  4096.0  476940.0            4,66      High
# 228  4096.0  476940.0            4,66      High
# 229  4096.0  476940.0            4,67      High
# 230  4096.0  476940.0            4,65      High
# 231  4096.0  305245.0             4,6      High
# 232  4096.0  476940.0            4,67      High
# 233  4096.0  476940.0            4,66      High
# 234  4096.0  305245.0             4,6      High
# 235  4096.0  476940.0            4,64      High
# 236  4096.0  305245.0             4,6      High

# %%
Rebu.describe()
# Out:
#              RAM.GB         HDD.MB
# count   2988.000000    2988.000000
# mean    3191.132530  208448.974230
# std     2000.143448  139380.153669
# min        0.000000       0.000000
# 25%     2048.000000  152627.000000
# 50%     4096.000000  157066.000000
# 75%     4096.000000  238475.000000
# max    16384.000000  953869.000000

# %%
#DATA ANALYSIS

# %%
# # Summary of numeric and categorical data
print(Rebu.describe(include='all'))
# Out:
#             Type  Subtype    Model Manufacturer  \
# count       2988     2988     2988         2988
# unique         1        7      473           55
# top     Computer  Desktop  6072V27       LENOVO
# freq        2988     2045      193         1030
# mean         NaN      NaN      NaN          NaN
# std          NaN      NaN      NaN          NaN
# min          NaN      NaN      NaN          NaN
# 25%          NaN      NaN      NaN          NaN
# 50%          NaN      NaN      NaN          NaN
# 75%          NaN      NaN      NaN          NaN
# max          NaN      NaN      NaN          NaN
#
#                            Registered.in                            Processor  \
# count                               2988                                 2988
# unique                              2988                                  265
# top     2018-07-27 10:05:48.290000+00:00  Intel Core2 Duo CPU E8400 @ 3.00GHz
# freq                                   1                                  455
# mean                                 NaN                                  NaN
# std                                  NaN                                  NaN
# min                                  NaN                                  NaN
# 25%                                  NaN                                  NaN
# 50%                                  NaN                                  NaN
# 75%                                  NaN                                  NaN
# max                                  NaN                                  NaN
#
#               RAM.GB         HDD.MB Condition.Score Condition
# count    2988.000000    2988.000000            2988      2988
# unique           NaN            NaN             368         4
# top              NaN            NaN            4,22      High
# freq             NaN            NaN             163      1313
# mean     3191.132530  208448.974230             NaN       NaN
# std      2000.143448  139380.153669             NaN       NaN
# min         0.000000       0.000000             NaN       NaN
# 25%      2048.000000  152627.000000             NaN       NaN
# 50%      4096.000000  157066.000000             NaN       NaN
# 75%      4096.000000  238475.000000             NaN       NaN
# max     16384.000000  953869.000000             NaN       NaN

# %%
#Unique Value Count
print(Rebu['Type'].value_counts())
print(Rebu['Subtype'].value_counts())
# Out:
# Computer    2988
# Name: Type, dtype: int64
# Desktop       2045
# Netbook        383
# Microtower     294
# Laptop         212
# Unknown         51
# Server           2
# SAI              1
# Name: Subtype, dtype: int64

# %%
#Manufacturer Overview
print(Rebu['Manufacturer'].value_counts())
# Out:
# LENOVO                           1030
# Hewlett-Packard                   914
# Dell Inc.                         279
# Acer                              261
# ASUSTeK Computer INC.             113
# Acer Inc.                          59
# Intel                              48
# Lenovo                             42
# HP Inc.                            36
# ACER                               34
# Sony Corporation                   18
# ASUS                               17
# Unknown                            16
# TOSHIBA                            12
# NEC Computers International        11
# Dell Inc                            8
# Gigabyte Technology Co., Ltd.       8
# MSI                                 7
# DataLogic                           7
# Dell                                5
# Apple Inc.                          4
# FUJITSU SIEMENS                     4
# IBM                                 4
# ECS                                 4
# Be quiet!                           4
# Toshiba                             3
# To Be Filled By O.E.M.              3
# HP                                  3
# ASUSTeK COMPUTER INC.               3
# ASUSTeK Computer Inc.               2
# NCR Corporation                     2
# Compaq                              2
# OEM00000                            2
# Packard Bell                        2
# Asus                                1
# Compaq-Presario                     1
# eMachines                           1
# Acer, inc.                          1
# Dell (subsidiary)                   1
# sony                                1
# Packard Bell BV                     1
# Digibras                            1
# BIOSTAR Group                       1
# POSITIVO BGH                        1
# SAMSUNG ELECTRONICS CO., LTD.       1
# FUJITSU                             1
# Medion                              1
# Gateway, Inc.                       1
# Gateway                             1
# lenovo                              1
# Packard Bell NEC                    1
# MAXDATA                             1
# COMPAQ                              1
# Sony                                1
# HP-Pavilion                         1
# Name: Manufacturer, dtype: int64

# %%
#Condition Distribution
print(Rebu['Condition.Score'].value_counts())
# Out:
# 4,22    163
# 4,23    120
# 1,03     99
# 2,22     78
# 4,52     69
#        ...
# 1,2       1
# 1,13      1
# 0,87      1
# 0,97      1
# 4,74      1
# Name: Condition.Score, Length: 368, dtype: int64

# %%
#CONDITION SCORE ANALYSIS
#Plotting the distribution of condition scores


import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(Rebu['Condition.Score'], kde=True, bins=10)
plt.title("Distribution of Condition Scores")
plt.xlabel("Condition Score")
plt.ylabel("Frequency")
plt.show()

# %%
# CONDITION BREAKDOWN -  REFURBISHMENT POTENTIAL ANALYSIS
# detecting the devices that are viable for refurbishment

# %%
print(Rebu['Condition.Score'].dtype)
# Out:
# object

# %%
Rebu['Condition.Score'] = pd.to_numeric(Rebu['Condition.Score'], errors='coerce')

# %%
#using a conditional statement, to determine the conditions for these items to be refurblished.


def categorize_condition(score):
    if score >= 4:
        return 'High'
    elif score >= 2:
        return 'Medium'
    elif score > 0:
        return 'Low'
    else:
        return 'Discard'

Rebu['Condition.Category'] = Rebu['Condition.Score'].apply(categorize_condition)
print(Rebu['Condition.Category'].value_counts())
# Out:
# Discard    2959
# Medium       17
# High         10
# Low           2
# Name: Condition.Category, dtype: int64

# %%
#The analysis above simply categorized the devices into four groups "High, Medium, Low, and Discard",  a lot of the devices fall in the 
#category of discard meaning they are not in good shape to be refurblished or they are very poor in condition.
#This distribution suggests that most of the stock requires significant attention to evaluate for recycling or refurbishing.
#Efforts should focus on identifying efficient ways to process the large number of discarded devices to maximize value recovery.

# %%
#Distribution of Categories from state of condition

# %%
print(Rebu['Condition.Category'].value_counts())
sns.countplot(data=Rebu, x='Condition.Category', order=['High', 'Medium', 'Low', 'Discard'])
plt.title("Condition Category Distribution")
plt.xlabel("Category")
plt.ylabel("Count")
plt.show()
# Out:
# Discard    2959
# Medium       17
# High         10
# Low           2
# Name: Condition.Category, dtype: int64

# %%
#Which manufacturer dominates each of the categories


print(Rebu.groupby('Condition.Category')['Manufacturer'].value_counts())
# Out:
# Condition.Category  Manufacturer
# Discard             LENOVO                           1019
#                     Hewlett-Packard                   900
#                     Dell Inc.                         279
#                     Acer                              261
#                     ASUSTeK Computer INC.             113
#                     Acer Inc.                          59
#                     Intel                              48
#                     Lenovo                             42
#                     HP Inc.                            36
#                     ACER                               34
#                     Sony Corporation                   18
#                     ASUS                               17
#                     Unknown                            16
#                     TOSHIBA                            12
#                     NEC Computers International        11
#                     Dell Inc                            8
#                     Gigabyte Technology Co., Ltd.       8
#                     DataLogic                           7
#                     MSI                                 7
#                     Dell                                5
#                     Apple Inc.                          4
#                     Be quiet!                           4
#                     ECS                                 4
#                     FUJITSU SIEMENS                     4
#                     IBM                                 4
#                     HP                                  3
#                     To Be Filled By O.E.M.              3
#                     Toshiba                             3
#                     ASUSTeK COMPUTER INC.               2
#                     ASUSTeK Computer Inc.               2
#                     Compaq                              2
#                     OEM00000                            2
#                     Packard Bell                        2
#                     Acer, inc.                          1
#                     Asus                                1
#                     BIOSTAR Group                       1
#                     COMPAQ                              1
#                     Compaq-Presario                     1
#                     Dell (subsidiary)                   1
#                     Digibras                            1
#                     Gateway                             1
#                     Gateway, Inc.                       1
#                     HP-Pavilion                         1
#                     MAXDATA                             1
#                     Medion                              1
#                     POSITIVO BGH                        1
#                     Packard Bell BV                     1
#                     Packard Bell NEC                    1
#                     SAMSUNG ELECTRONICS CO., LTD.       1
#                     Sony                                1
#                     eMachines                           1
#                     lenovo                              1
#                     sony                                1
# High                Hewlett-Packard                     5
#                     LENOVO                              4
#                     FUJITSU                             1
# Low                 NCR Corporation                     2
# Medium              Hewlett-Packard                     9
#                     LENOVO                              7
#                     ASUSTeK COMPUTER INC.               1
# Name: Manufacturer, dtype: int64

# %%
#Checking the relationships that exist between the values we have in Numerical type using heatmap- Condition.Score, RAM, and HDD

# %%
sns.heatmap(Rebu[['Condition.Score', 'RAM.GB', 'HDD.MB']].corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
#This heatmap shows the correlation between three variables specifically "Condition Score, RAM.GB and HDD.MB". 
#Using the result, we can measure how closely related two variables are on a scale of -1 to 1.

# %%
# At 1, it means a Perfect positive correlation such that when one increases, the other also increases.
#At 0, there is no correlation, no relationship at all between the two variables.
# At -1, there is Perfect negative correlation when one increases, the other decreases.


#From the result, we can see that there is a strong correlation between the device condition score and the RAM size,
#simply implying tat devices with larger size of RAM tend to have higher condition scores, could be as a result of its newer state.
#There's a moderately strong positive correlation between the device's condition score and the storage capacity (HDD)
#There is a moderate positive correlation between RAM size and storage capacity (HDD)

# %%
#The Condition.Score measures the device health or quality and this is closely tied to its RAM and HDD capacity.
# Devices with better specifications are likely in better condition.With this, it is recommended that with this insights,
#Priority should be placed on devices for sales based on their RAM and HDD as it strongly influence the device condition.

# %%
#MANUFACTURER AND MODEL RELIABILITY
#using this information, we would be able to understand which brands and models are the most durable or suitable for circularity

# %%
# Top Models for Circularity

print(Rebu.groupby(['Manufacturer', 'Model'])['Condition.Score'].mean().sort_values(ascending=False).head(10))
# Out:
# Manufacturer           Model
# LENOVO                 5485W4R                               4.0
# FUJITSU                LIFEBOOK T730                         4.0
# Hewlett-Packard        HP Compaq dc5800 Microtower           4.0
# LENOVO                 6072V27                               4.0
# ASUSTeK COMPUTER INC.  1025CE                                3.0
# Hewlett-Packard        HP Compaq dc7700 Small Form Factor    3.0
# LENOVO                 9489W42                               2.0
#                        8918DEG                               2.0
# Hewlett-Packard        Unknown                               2.0
#                        HP dc5000 SFF(DX854AV)                2.0
# Name: Condition.Score, dtype: float64

# %%
#Plotting the average condition per manufacturer

avg_condition = Rebu.groupby('Manufacturer')['Condition.Score'].mean().sort_values()
avg_condition.plot(kind='barh', figsize=(10, 8))
plt.title("Average Condition Score by Manufacturer")
plt.xlabel("Average Condition Score")
plt.ylabel("Manufacturer")
plt.show()

# %%
#ENVIRONMENTAL IMPACT ANALYSIS

#Understanding how refublishing these devices contribute to sustainability

# %%
#Calculating the percentage of devices in High, Medium and Low condition to determine E-waste Reduction potentials

total_devices = len(Rebu)
refurbished_potential = Rebu[Rebu['Condition.Category'] != 'Discard'].shape[0]
waste_diversion_rate = (refurbished_potential / total_devices) * 100
print(f"Waste Diversion Rate: {waste_diversion_rate:.2f}%")
# Out:
# Waste Diversion Rate: 0.97%

# %%
#Estimated CO₂ reduction bu comparing it to the manufacturing of a new device, Assume refurbishing a device saves X kg of CO₂

co2_saved_per_device = 50  # Example value in kg
total_co2_saved = refurbished_potential * co2_saved_per_device
print(f"Estimated CO₂ Savings: {total_co2_saved:.2f} kg")
# Out:
# Estimated CO₂ Savings: 1450.00 kg

# %%
# analyzing refurbishment cost vs. ROI based on specifications like Processor, RAM.GB, and HDD.MB.

#Device Specs Distribution
print(Rebu[['Processor', 'RAM.GB', 'HDD.MB']].describe())
# Out:
#              RAM.GB         HDD.MB
# count   2988.000000    2988.000000
# mean    3191.132530  208448.974230
# std     2000.143448  139380.153669
# min        0.000000       0.000000
# 25%     2048.000000  152627.000000
# 50%     4096.000000  157066.000000
# 75%     4096.000000  238475.000000
# max    16384.000000  953869.000000

# %%
#Analysing how device type condition varies by type
condition_type = Rebu.groupby(['Type', 'Condition.Category']).size().unstack()
condition_type.plot(kind='bar', stacked=True, figsize=(10, 6), color=['green', 'orange', 'red', 'gray'])
plt.title('Device Type vs Condition Categories')
plt.xlabel('Device Type')
plt.ylabel('Count')
plt.legend(title='Condition Category')
plt.show()

# %%
# a pie charge overview of device condition categories (high, medium, low, discard).

# %%
condition_counts = Rebu['Condition.Category'].value_counts()
condition_counts.plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8), colors=['green', 'orange', 'red', 'gray'])
plt.title('Proportion of Condition Categories')
plt.ylabel('')
plt.show()

# %%
#Manifactureres contributing the most to discarded or low-condition devices

# %%
discarded_devices = Rebu[Rebu['Condition.Category'] == 'Discard']['Manufacturer'].value_counts()
discarded_devices.plot(kind='barh', figsize=(8, 6), color='darkred')
plt.title('Top Manufacturers of Discarded Devices')
plt.xlabel('Count')
plt.ylabel('Manufacturer')
plt.show()

# %%
#Analyzing how RAM Size and HDD size impact the condition scores of devices
#With minimum hardware threshold for better scores and detecting upgrading opportunities with low scores

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='RAM.GB', y='Condition.Score', data=Rebu, hue='Condition.Category', palette='viridis')
plt.title('Impact of RAM on Condition Score')
plt.xlabel('RAM (GB)')
plt.ylabel('Condition Score')
plt.show()

plt.figure(figsize=(8, 6))
sns.scatterplot(x='HDD.MB', y='Condition.Score', data=Rebu, hue='Condition.Category', palette='plasma')
plt.title('Impact of HDD on Condition Score')
plt.xlabel('HDD (MB)')
plt.ylabel('Condition Score')
plt.show()

# %%
# Determining how the number of devices in the dataset changes over time.

# %%
Rebu['Registered.in'] = pd.to_datetime(Rebu['Registered.in'])
registration_trend = Rebu.groupby(Rebu['Registered.in'].dt.to_period('M')).size()
registration_trend.plot(kind='line', figsize=(10, 6), marker='o', color='blue')
plt.title('Device Registration Trends Over Time')
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Chika\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:1162: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   warnings.warn(
